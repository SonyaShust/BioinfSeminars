# %%
c=input("Enter the temperature:")
F = (int(c)* 9/5) + 32
print(F)
# Out:
# 41.0

# %%
first_name=input("Name:")
last_name=input("Last name:")
print(first_name+" "+last_name)
# Out:
# Lola Dou

# %%
length=int(input("length:"))
width=int(input("width:"))
area = (length * width)
print(area)
# Out:
# 16

# %%
a, b = 10, 3
print("Slogenie:", a + b)
print("Vichitanie", a - b)
print("Slogenie:", a * b)
print("Delenie:", a / b)
print("Stepen':", a ** b)
# Out:
# Slogenie: 13
# Vichitanie 7
# Slogenie: 30
# Delenie: 3.3333333333333335
# Stepen': 1000

# %%
word=input("Word:")
print("Letters:", len(word))
# Out:
# Letters: 3

# %%
n = int(int(input("Number:"))%2==0)
w=not n
print("even"*n, "odd"*w)
# Out:
# even

# %%
word = input("Word:")
n = int(input("сколько раз повторить:"))
s=word*n
print(word*n)
# Out:
# uuu

# %%
mint=int(input("minutes:"))
h=mint // 60
min= mint % 60
print (f"{mint} мин = {h} ч {min} мин")
# Out:
# 230 мин = 3 ч 50 мин

# %%
a = float(input("a:"))
b = float(input("b:"))
c = float(input("c:"))
p=(a+b+c) / 2
s =(p * (p - a) * (p - b) * (p - c))**0.5
print("площадь=", s)
# Out:
# площадь= 2.9047375096555625

# %%
t = input("введите строку:")
f_3 = t[:3]
l_3 = t[-3:]
print("First 3:", f_3)
print("Last 3:", l_3)
# Out:
# First 3: poi
# Last 3: ytr

# %%
t = input("введите строку:")
rt = t[::-1]
print(rt)
# Out:
# fot

# %%
t = input("введите строку:")
ft = input("введите подстроку:")
r = ft in t
a = ["no", "yes"][r]
print(a)
# Out:
# no
