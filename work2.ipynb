# %%
a = int (input ("число:"))
if a < 0 : print ("-")
elif a > 0 : print ("+")
elif a == 0 : print ("0")
# Out:
# +

# %%
a = int (input ("число:"))
while True:
          if a == 0 : print ("0")
          break
if a < 0 : print ("-")
elif a > 0 : print ("+")
# Out:
# 0

# %%
for i in range(1,51):
  if i%2 == 0: print (i * 2)
  elif i%2 == 1: print (i / 3)
# Out:
# 0.3333333333333333
# 4
# 1.0
# 8
# 1.6666666666666667
# 12
# 2.3333333333333335
# 16
# 3.0
# 20
# 3.6666666666666665
# 24
# 4.333333333333333
# 28
# 5.0
# 32
# 5.666666666666667
# 36
# 6.333333333333333
# 40
# 7.0
# 44
# 7.666666666666667
# 48
# 8.333333333333334
# 52
# 9.0
# 56
# 9.666666666666666
# 60
# 10.333333333333334
# 64
# 11.0
# 68
# 11.666666666666666
# 72
# 12.333333333333334
# 76
# 13.0
# 80
# 13.666666666666666
# 84
# 14.333333333333334
# 88
# 15.0
# 92
# 15.666666666666666
# 96
# 16.333333333333332
# 100

# %%
import random 
a = random.randint(1, 100)
for chance in range(10):
    att = int (input ("Введите число:"))
    if att == a:
        print (att, "Вы победили")
        break
    elif att > a:
        print (att, "Больше")
    elif att < a:
        print (att, "Меньше")
else : print ("Попытки закончились")
# Out:
# 12 Меньше
# 34 Меньше
# 56 Меньше
# 78 Больше
# 90 Больше
# 60 Меньше
# 6 Меньше
# 66 Меньше
# 70 Меньше
# 77 Больше
# Попытки закончились

# %%
a = input ("Введите выражение через пробелы:")
s1 =

# %%
n = 4
for i in range(n):
    if i == 0:
        print("*" * (2 * n - 1))
    elif i == 3: print(" " * i + "*")
    else: print (" " * i + "*" + " " * (2 * (n - i) - 3) + "*")
for i in range(n - 2, -1, -1):
    if i == 0:
        print("*" * (2 * n - 1))
    elif i == 3: print(" " * i + "*")
    else: print (" " * i + "*" + " " * (2 * (n - i) - 3) + "*")
# Out:
# *******
#  *   *
#   * *
#    *
#   * *
#  *   *
# *******

# %%
start = int (input ("Введите начало интервала:"))
end = int (input ("Введите конец интервала:"))
for num in range (start, end + 1):
    if num > 1:
        prost = True 
        for i in range (2, num):
            if num % i == 0: 
                prost = False
                break
        if prost:
            print (num, end = " ")
# Out:
# 2 3 5 7

# %%
v = input ("Введите числа через пробелы")
a, b =  map(float, v. split())
n = input ("Введите символ операции")
if n == "+":
    print (a + b)
elif n == "-":
    print (a - b)
elif n == "*":
    print(a * b)
elif n == "/" :
    print (a / b)

# %%
x = int (input("Введите первоначальную сумму")) 
p = int (input("Введите проценты в виде %"))
y = int (input("Введите сумму, не меньше которой должен быть после n лет"))
n= 0
while True:
 if (x * ((1 + (p / 100)) ** n)) >= y :
     print ("n лет:", n)
     break
 n +=1

# %%
string = input("numbers:")
p = string.split()
nums=[]
for part in p:
    nums.append(int(part))
nums.sort(reverse=True)
answer=nums[1]
print(answer)

# %%
n = int(input("Введите числo:"))
res = 1
for i in range (1, n + 1):
    res = res * i
print(res)

# %%
n = int(input("Введите № числa:"))
if n<=0:
    print ("Error")
elif n==1 or n==2:
    res=1
else:
    p1 = 1
    p2 = 1
    for i in range (3, n+1):
       c = p1 + p2
       p2 = p1
       p1 = c
    res = p1
print (res)
